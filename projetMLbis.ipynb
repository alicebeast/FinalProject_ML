# %%
import pandas as pd
import os
path = os.getcwd()
train_path = path + r"\data\train.parquet"
test_path = path + r"\data\train.parquet"


train = pd.read_parquet(train_path)
train.sample(10)
# Out:
#         sensor          time        power  temperature
# 3465029   N634  4.765478e+09     0.000000    22.047401
# 5542504   N582  1.562198e+09  1400.000000    24.486387
# 3737457   N744  3.546202e+09  1000.000000    38.961960
# 1017290   N548  3.526330e+09   474.114319    23.219389
# 5888528   N717  8.364384e+08  1400.000000    26.942549
# 4302693   N915  2.941315e+09  1000.000000    47.604557
# 852837    N439  3.397594e+09   485.122925    19.754883
# 1994086   N900  3.612730e+09   467.100861    24.347141
# 2842494   N316  3.184186e+09  1000.000000    32.414692
# 2998679   N410  4.056048e+09   500.000000    23.522696

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\alice\\OneDrive - epfl.ch\\Documents\\GitHub\\FinalProject_ML'

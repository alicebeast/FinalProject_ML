# %% [markdown]
# # IntroML2026 Final Project : Predicting Nuclear Waste Temperature

# %% [markdown]
# **Group name :** à déterminer
#
# **Authors:** Alice Verniquet and Laura Monney

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# <div style="text-align: justify;">
# This project aims to predict the temperature evolution around nuclear waste canisters
# using measurements from approximately 300 sensors and known heating power values.
# The data spans three different experimental modes, each with distinct heating profiles.
# Our goal is to build a machine learning model that can generalize to unseen sensor
# locations, potentially replacing computationally expensive methods such as finite element simulations.
# </div>

# %% [markdown]
# # 2. Imports and data loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import helpers
from sklearn.preprocessing import StandardScaler
path = os.getcwd()
train_path = path + r"\data\train.parquet"
test_path = path + r"\data\test.parquet"
sensors_path = path + r"\data\sensors.parquet"

#data loading
train = pd.read_parquet(train_path)
test = pd.read_parquet(test_path)
sensors = pd.read_parquet(sensors_path)
print(test.columns.tolist())
# Out:
# ['sensor', 'time', 'power']

# %% [markdown]
# # 3. Data exploration

# %%
#displaying the first rows of the dataframes
sensors.head()
# Out:
#   sensor  coor_x  coor_y  coor_z
# 0     N2     0.5     0.0     0.0
# 1     N4     1.4     0.0     0.0
# 2     N5     0.5     2.4     0.0
# 3     N6     0.0     2.4     0.0
# 4     N7     0.0     3.5     0.0

# %%
#inspecting the dataframes
print(train.info())
print(sensors.shape)
print(test.shape)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6626928 entries, 0 to 6626927
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   sensor       category
#  1   time         float64
#  2   power        float32
#  3   temperature  float32
# dtypes: category(1), float32(2), float64(1)
# memory usage: 113.8 MB
# None
# (325, 4)
# (2190480, 3)

# %%
#Statistics
train.describe(include="all")
# Out:
#          sensor          time         power   temperature
# count   6626928  6.626928e+06  6.626928e+06  6.527525e+06
# unique      242           NaN           NaN           NaN
# top        N102           NaN           NaN           NaN
# freq      27384           NaN           NaN           NaN
# mean        NaN  3.942130e+09  5.549463e+02  4.706070e+01
# std         NaN  2.275997e+09  5.258427e+02  3.897674e+02
# min         NaN  0.000000e+00  0.000000e+00 -2.921508e+02
# 25%         NaN  1.971605e+09  0.000000e+00  1.566275e+01
# 50%         NaN  3.942432e+09  4.445813e+02  1.939439e+01
# 75%         NaN  5.913173e+09  1.000000e+03  2.877052e+01
# max         NaN  7.884000e+09  1.500000e+03  6.039050e+03

# %%
#detecting missing values
train.isna().any()
# Out:
# sensor         False
# time           False
# power          False
# temperature     True
# dtype: bool

# %%
#finding the number of the two sensors which are very far from our expected values; outliers
neg_outlier = train[train['temperature'] == train['temperature'].min()]
pos_outlier = train[train['temperature'] == train['temperature'].max()]
print(neg_outlier['sensor'], pos_outlier['sensor'])
# Out:
# 483784     N277
# 483785     N277
# 483786     N277
# 483787     N277
# 483788     N277
#            ...
# 4910859    N277
# 4910860    N277
# 4910861    N277
# 4910862    N277
# 4910863    N277
# Name: sensor, Length: 27384, dtype: category
# Categories (242, str): ['N102', 'N103', 'N108', 'N112', ..., 'N926', 'N927', 'N928', 'N96'] 2181592    N927
# 2181593    N927
# 2181594    N927
# 2181595    N927
# 2181596    N927
#            ...
# 6608667    N927
# 6608668    N927
# 6608669    N927
# 6608670    N927
# 6608671    N927
# Name: sensor, Length: 27384, dtype: category
# Categories (242, str): ['N102', 'N103', 'N108', 'N112', ..., 'N926', 'N927', 'N928', 'N96']

# %%
#visualization
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

train.plot(kind='scatter', x='time', y='power', ax=axes[0,0], title='Power over time', s=1)
train.plot(kind='scatter', x='time', y='temperature', alpha=0.3, ax=axes[0,1], title='Temperature over time', s=1)
train.plot(kind='scatter', x='sensor', y='temperature', alpha=0.15, ax=axes[1,0], title='Temperature per sensor', s=1)
sensors.plot(kind='scatter', x='coor_x', y='coor_y', ax=axes[1,1], title='Sensor positions')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Key Observations
#
# <div style="text-align: justify;">
# Through the exploratory data analysis, we identified several important characteristics
# of the dataset that will guide our preprocessing steps :
#
# - **Missing values :** 99403 temperature values are missing across multiple sensors
# and will need to be imputed before training.
#
# - **Outlier sensors :** Two sensors (N277 and N927) show clearly aberrant temperature
# values (below -292°C and above 6039°C) and will be removed entirely.
#
# - **3 experimental modes :** The power-time plot reveals 3 distinct heating profiles,
# suggesting the data contains 3 separate experiments that should be treated independently.
#
# - **Sensor positions :** The sensors are not evenly distributed in space,
# which means a simple global average would be biased when imputing missing values.
#
# - **Temperature range :** Most sensors record temperatures between 14°C and 30°C,
# with a few reaching higher values close to the canister.
# </div>

# %% [markdown]
# # 4. Preprocessing

# %% [markdown]
# ## 4.1 Missing values

# %% [markdown]
# <div style="text-align: justify;">
# We use linear interpolation grouped by sensor because the data is ordered
# chronologically. This preserves the temporal evolution of each sensor better
# than a global mean, which would ignore the time structure.
# </div>

# %%
#visualize the missing values
missing_idx = train[train['temperature'].isna()].index
print(missing_idx)
print(len(missing_idx))
# Out:
# Index([    106,     364,     477,     501,     568,     657,     712,     769,
#            833,     870,
#        ...
#        6626263, 6626302, 6626312, 6626504, 6626575, 6626627, 6626671, 6626726,
#        6626890, 6626924],
#       dtype='int64', length=99403)
# 99403

# %%
#see where the missing values are --> a bit everywhere
sensors_misval = train.loc[missing_idx, 'sensor'].unique()
sensors_misval_coords = sensors[sensors['sensor'].isin(sensors_misval)]

sensors_misval_coords.plot(kind='scatter', x='coor_x', y='coor_y')
plt.show()

# %%
#fills the missing temperature by using interpolate because our data is ordered chronologically 
#and taking into account ouly values from the same sensor
train['temperature'] = (
    train.groupby('sensor')['temperature']
    .transform(lambda x: x.interpolate(method='linear', limit_direction='both'))
)

# %%
#control that every missing values are replaced
train.isna().any()
# Out:
# sensor         False
# time           False
# power          False
# temperature    False
# dtype: bool

# %% [markdown]
# ## 4.2 Remove outliers

# %%
#get rid of the outlier sensors
train = train[train["sensor"] != "N277"]
train = train[train["sensor"] != "N927"]
sensors = sensors[sensors["sensor"] != "N277"]
sensors = sensors[sensors["sensor"] != "N927"]

# %%
#verify that the outlier sensors are gone
np.all(train["sensor"] != 'N277') and np.all(train["sensor"] != 'N927')
# Out:
# np.True_

# %%
#control if values are reasonable
print("Min température:", train['temperature'].min())
print("Max température:", train['temperature'].max())
print("Mean température:", train['temperature'].mean())
# Out:
# Min température: -119.05078
# Max température: 186.7141
# Mean température: 23.145048

# %%
# Voir la distribution des températures par capteur
temp_stats = train.groupby('sensor')['temperature'].agg(['mean', 'std', 'min', 'max'])

# Visualiser les capteurs avec une variance anormalement élevée
temp_stats['std'].hist(bins=50)
plt.title('Distribution des écarts-type par capteur')
plt.xlabel('std')
plt.ylabel('nombre de capteurs')
plt.show()

print(temp_stats.sort_values('std', ascending=False).head(10))
# Out:
#              mean        std         min         max
# sensor
# N918     9.296401  30.363062  -33.844723   60.355274
# N200    30.144228  29.024006  -97.490067  179.888260
# N6      30.042862  28.986866  -99.829506  178.348999
# N201    30.139454  28.971140  -99.214371  175.821671
# N5      30.145496  28.926306  -99.559898  173.701843
# N202    30.127878  28.908621 -100.193153  171.754608
# N197    30.149328  28.890343  -98.977097  171.470490
# N203    30.183672  28.865175  -97.795731  174.556686
# N204    11.453159  28.363346 -119.050781  153.614197
# N917    29.100103  26.412840  -97.562920  167.852036

# %%
# Visualiser les températures de N918 et N204 dans le temps
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

train[train['sensor'] == 'N918'].plot(
    x='time', y='temperature', ax=axes[0], title='N918', s=1, kind='scatter')

train[train['sensor'] == 'N204'].plot(
    x='time', y='temperature', ax=axes[1], title='N204', s=1, kind='scatter')

plt.tight_layout()
plt.show()

# %%
# Quelle proportion des données de N204 sont des outliers ?
total_n204 = len(train[train['sensor'] == 'N204'])
outliers_n204 = len(train[(train['sensor'] == 'N204') & 
                           ((train['temperature'] > 75) | 
                            (train['temperature'] < -50))])

print(f"Total lignes N204 : {total_n204}")
print(f"Outliers évidents : {outliers_n204}")
print(f"Proportion : {outliers_n204/total_n204*100:.1f}%")
# Out:
# Total lignes N204 : 27384
# Outliers évidents : 113
# Proportion : 0.4%

# %%
# Filtrer les outliers évidents de N204

mask_n204 = (train['sensor'] == 'N204') & (
    (train['temperature'] > 60) | 
    (train['temperature'] < -30)
)

print(f"Lignes supprimées : {mask_n204.sum()}")
train = train[~mask_n204]

# Vérification visuelle
train[train['sensor'] == 'N204'].plot(
    x='time', y='temperature', s=1, kind='scatter', title='N204 après filtrage v2')
plt.show()
# Out:
# Lignes supprimées : 155

# %%
# Appliquer un filtre global sur toutes les températures aberrantes
# D'abord voir la distribution globale
train['temperature'].hist(bins=100)
plt.title('Distribution globale des températures')
plt.xlabel('température')
plt.show()

print(f"Températures < -30 : {(train['temperature'] < -30).sum()}")
print(f"Températures > 150 : {(train['temperature'] > 150).sum()}")
# Out:
# Températures < -30 : 14437
# Températures > 150 : 222

# %%
# Capteurs avec des températures < -30
print("Capteurs avec temp < -30:")
print(train[train['temperature'] < -30]['sensor'].value_counts().head(10))

print("\nCapteurs avec temp > 150:")
print(train[train['temperature'] > 150]['sensor'].value_counts().head(10))
# Out:
# Capteurs avec temp < -30:
# sensor
# N918    1281
# N345     114
# N383     110
# N279     107
# N583     107
# N281     106
# N493     104
# N786     103
# N74      100
# N302      99
# Name: count, dtype: int64
#
# Capteurs avec temp > 150:
# sensor
# N196    18
# N200    16
# N5      10
# N921    10
# N202     9
# N197     8
# N917     8
# N201     7
# N6       7
# N905     7
# Name: count, dtype: int64

# %%
# Visualiser N196
train[train['sensor'] == 'N196'].plot(
    x='time', y='temperature', s=1, kind='scatter', title='N196')
plt.show()

# %%
before = len(train)
train = train[(train['temperature'] >= -30) & (train['temperature'] <= 190)]
after = len(train)
print(f"Lignes supprimées : {before - after}")
print(f"Soit {(before-after)/before*100:.2f}% des données")
# Out:
# Lignes supprimées : 14437
# Soit 0.22% des données

# %%
for sensor in ['N204', 'N196']:
    train = train[train['sensor'] != sensor]
    sensors = sensors[sensors['sensor'] != sensor]
    
print(f"Capteurs défectueux supprimés !")
print(f"Taille train : {len(train)}")
# Out:
# Capteurs défectueux supprimés !
# Taille train : 6502995

# %%
#Visualization after getting rid of the two bad sensors
train.plot(kind='scatter', x='sensor', y='temperature', alpha=0.15)
# Out:
# <Axes: xlabel='sensor', ylabel='temperature'>

# %% [markdown]
# ## 4.3 Merge coordinates with the training data

# %%
# merge the train dataframe with the sensors dataframe to get the coordinates of each sensor
train = train.merge(sensors[['sensor', 'coor_x', 'coor_y', 'coor_z']], on='sensor', how='left')

# Ajout de la distance au centre du conteneur
train['distance'] = np.sqrt(train['coor_x']**2 + train['coor_y']**2)
# control
print(train.columns)
# Out:
# Index(['sensor', 'time', 'power', 'temperature', 'coor_x', 'coor_y', 'coor_z',
#        'distance'],
#       dtype='str')

# %% [markdown]
# ## 4.3 Normalisation

# %% [markdown]
# <div style="text-align: justify;">
# We normalize time and power using StandardScaler because their scales differ
# greatly (billions vs 0-1500). This ensures that no feature dominates the model
# simply due to its magnitude.
# </div>

# %%
# Normalisation of time and power
scaler = StandardScaler()
train[['time', 'power']] = scaler.fit_transform(train[['time', 'power']])

# Normalisation of coordinates
scaler_coords = StandardScaler()
train[['coor_x', 'coor_y', 'coor_z']] = scaler_coords.fit_transform(
    train[['coor_x', 'coor_y', 'coor_z']]
)

# Verification
print(train[['time', 'power', 'coor_x', 'coor_y', 'coor_z']].describe())
# Out:
#                time         power        coor_x        coor_y     coor_z
# count  6.502995e+06  6.502995e+06  6.502995e+06  6.502995e+06  6502995.0
# mean  -6.153744e-18  1.079702e-16  1.321506e-08  2.162465e-08        0.0
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00        0.0
# min   -1.731678e+00 -1.055908e+00 -1.003078e+00 -1.685279e+00        0.0
# 25%   -8.659358e-01 -1.055908e+00 -8.321786e-01 -8.806449e-01        0.0
# 50%   -1.934200e-04 -2.095690e-01 -3.496426e-01  1.133840e-03        0.0
# 75%    8.659666e-01  8.456152e-01  6.008313e-01  8.880432e-01        0.0
# max    1.732886e+00  1.796377e+00  2.660440e+00  1.508282e+00        0.0

# %% [markdown]
# ## 4.4 Separation of modes

# %% [markdown]
# <div style="text-align: justify;">
# The power-time plot reveals 3 distinct experimental modes. Since each sensor has
# 27384 timesteps split into 3 equal blocks of 9128, we separate them by dividing
# the dataset into 3 equal parts of 2190720 rows each.
# </div>

# %%
#separate out three modes so that we can try different models for different modes
BLOCK = len(train) // 3

mode1 = train.iloc[0       : BLOCK].copy()
mode2 = train.iloc[BLOCK   : 2*BLOCK].copy()
mode3 = train.iloc[2*BLOCK :].copy()

# Control
print(mode1.shape, mode2.shape, mode3.shape)

# Visualization of the three modes
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

mode1.plot(kind='scatter', x='time', y='power', ax=axes[0], title='Mode 1', s=1)
mode2.plot(kind='scatter', x='time', y='power', ax=axes[1], title='Mode 2', s=1)
mode3.plot(kind='scatter', x='time', y='power', ax=axes[2], title='Mode 3', s=1)

plt.tight_layout()
plt.show()
# Out:
# (2167665, 8) (2167665, 8) (2167665, 8)

# %% [markdown]
# # 5. Model Training

# %% [markdown]
# blablabla c'est ici qu'on teste plusieurs modèles, voilàààààà

# %% [markdown]
# ## 5.1 Linear regression

# %% [markdown]
# résultat sur le learderboard : 7.87198

# %%
from sklearn.model_selection import train_test_split

# Définir les features et la target manuellement
features = ['time', 'power', 'coor_x', 'coor_y', 'coor_z', 'distance']
target = 'temperature'

X = train[features].values
y = train[target].values

# Séparer en train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
# Out:
# X_train shape: (5202396, 6)
# X_test shape: (1300599, 6)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Créer et entraîner le modèle
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# Prédictions
y_pred_train = lr_model.predict(X_train)
y_pred_test = lr_model.predict(X_test)

# Evaluer avec RMSE
rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))

print(f"RMSE Train: {rmse_train:.4f}")
print(f"RMSE Test:  {rmse_test:.4f}")
# Out:
# RMSE Train: 10.9159
# RMSE Test:  10.9408

# %%
# 1. D'abord supprimer les doublons
sensors_clean = sensors.drop_duplicates(subset='sensor')

# 2. Ensuite merger
test = test.merge(sensors_clean[['sensor', 'coor_x', 'coor_y', 'coor_z']], on='sensor', how='left')
# Ajout de la distance au centre du conteneur
test['distance'] = np.sqrt(test['coor_x']**2 + test['coor_y']**2)

# Vérification cruciale
print(f"Nombre de lignes test après merge : {len(test)}")
# Ce nombre doit être 2190480
# Out:
# Nombre de lignes test après merge : 2190480

# %%
# Normalisation de test avec les mêmes scalers que le train
test[['time', 'power']] = scaler.transform(test[['time', 'power']])
test[['coor_x', 'coor_y', 'coor_z']] = scaler_coords.transform(test[['coor_x', 'coor_y', 'coor_z']])

print("test après normalisation:")
print(test[['time', 'power', 'coor_x', 'coor_y']].describe())
# Out:
# test après normalisation:
#                time         power        coor_x        coor_y
# count  2.190480e+06  2.190480e+06  2.190480e+06  2.190480e+06
# mean   8.507264e-04 -7.845498e-04 -3.812287e-03 -1.266449e-01
# std    1.000060e+00  9.998522e-01  9.735750e-01  1.071665e+00
# min   -1.731298e+00 -1.055908e+00 -1.003078e+00 -1.685279e+00
# 25%   -8.651764e-01 -1.055908e+00 -8.377516e-01 -9.843426e-01
# 50%    9.835826e-04 -2.106953e-01 -2.149666e-01 -2.502544e-01
# 75%    8.671056e-01  8.456152e-01  4.925979e-01  8.325968e-01
# max    1.732886e+00  1.796377e+00  2.660440e+00  1.508282e+00

# %%
# Prédictions sur le vrai test set
#X_kaggle = test[['time', 'power', 'coor_x', 'coor_y', 'coor_z']].values
#y_pred = lr_model.predict(X_kaggle)

#print(f"Prédictions générées : {len(y_pred)} lignes")
#print(y_pred[:10])
#print(y_pred.min(), y_pred.max())

# %%
import matplotlib.pyplot as plt
test['power'].plot()
plt.title('Power in test')
plt.show()

# %% [markdown]
# # NN

# %% [markdown]
# score sur le leaderbord : 4.74

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# Vérifier si GPU disponible
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device utilisé : {device}")

# Définition du MLP
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(5, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )
    
    def forward(self, x):
        return self.network(x)
# Out:
# Device utilisé : cpu

# %%
def train_mlp(X_train, y_train, X_val, y_val, n_epochs=20):
    """Entraîne un MLP sur un mode donné et retourne le modèle entraîné."""
    
    X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train_t = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
    X_val_t = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val_t = torch.tensor(y_val, dtype=torch.float32).unsqueeze(1).to(device)
    
    dataset = TensorDataset(X_train_t, y_train_t)
    loader = DataLoader(dataset, batch_size=4096, shuffle=True)
    
    model = MLP().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    criterion = nn.MSELoss()
    
    for epoch in range(n_epochs):
        model.train()
        for X_batch, y_batch in loader:
            optimizer.zero_grad()
            loss = criterion(model(X_batch), y_batch)
            loss.backward()
            optimizer.step()
        
        model.eval()
        with torch.no_grad():
            rmse = torch.sqrt(criterion(model(X_val_t), y_val_t)).item()
        print(f"Epoch {epoch+1}/{n_epochs} | RMSE Val: {rmse:.4f}")
    
    return model

# Séparer train en 3 modes
BLOCK = len(train) // 3
mode1 = train.iloc[0      : BLOCK].copy()
mode2 = train.iloc[BLOCK  : 2*BLOCK].copy()
mode3 = train.iloc[2*BLOCK:].copy()

features = ['time', 'power', 'coor_x', 'coor_y', 'distance']
target = 'temperature'

# Entraîner un modèle par mode
print("=== MODE 1 ===")
X1 = mode1[features].values
y1 = mode1[target].values
X1_train, X1_val, y1_train, y1_val = train_test_split(X1, y1, train_size=0.8, random_state=42)
model1 = train_mlp(X1_train, y1_train, X1_val, y1_val)

print("=== MODE 2 ===")
X2 = mode2[features].values
y2 = mode2[target].values
X2_train, X2_val, y2_train, y2_val = train_test_split(X2, y2, train_size=0.8, random_state=42)
model2 = train_mlp(X2_train, y2_train, X2_val, y2_val)

print("=== MODE 3 ===")
X3 = mode3[features].values
y3 = mode3[target].values
X3_train, X3_val, y3_train, y3_val = train_test_split(X3, y3, train_size=0.8, random_state=42)
model3 = train_mlp(X3_train, y3_train, X3_val, y3_val)
# Out:
# === MODE 1 ===
# Epoch 1/20 | RMSE Val: 12.3896
# Epoch 2/20 | RMSE Val: 7.1089
# Epoch 3/20 | RMSE Val: 6.8625
# Epoch 4/20 | RMSE Val: 6.7705
# Epoch 5/20 | RMSE Val: 6.7316
# Epoch 6/20 | RMSE Val: 6.7095
# Epoch 7/20 | RMSE Val: 6.6776
# Epoch 8/20 | RMSE Val: 6.6599
# Epoch 9/20 | RMSE Val: 6.6406
# Epoch 10/20 | RMSE Val: 6.6254
# Epoch 11/20 | RMSE Val: 6.6109
# Epoch 12/20 | RMSE Val: 6.5977
# Epoch 13/20 | RMSE Val: 6.5813
# Epoch 14/20 | RMSE Val: 6.5658
# Epoch 15/20 | RMSE Val: 6.5498
# Epoch 16/20 | RMSE Val: 6.5357
# Epoch 17/20 | RMSE Val: 6.5212
# Epoch 18/20 | RMSE Val: 6.5084
# Epoch 19/20 | RMSE Val: 6.4976
# Epoch 20/20 | RMSE Val: 6.4843
# === MODE 2 ===
# Epoch 1/20 | RMSE Val: 13.3314
# Epoch 2/20 | RMSE Val: 7.8030
# Epoch 3/20 | RMSE Val: 7.1026
# Epoch 4/20 | RMSE Val: 6.9288
# Epoch 5/20 | RMSE Val: 6.8526
# Epoch 6/20 | RMSE Val: 6.8113
# Epoch 7/20 | RMSE Val: 6.7722
# Epoch 8/20 | RMSE Val: 6.7435
# Epoch 9/20 | RMSE Val: 6.7195
# Epoch 10/20 | RMSE Val: 6.7003
# Epoch 11/20 | RMSE Val: 6.6713
# Epoch 12/20 | RMSE Val: 6.6466
# Epoch 13/20 | RMSE Val: 6.6269
# Epoch 14/20 | RMSE Val: 6.6032
# Epoch 15/20 | RMSE Val: 6.5821
# Epoch 16/20 | RMSE Val: 6.5640
# Epoch 17/20 | RMSE Val: 6.5408
# Epoch 18/20 | RMSE Val: 6.5203
# Epoch 19/20 | RMSE Val: 6.4946
# Epoch 20/20 | RMSE Val: 6.4747
# === MODE 3 ===
# Epoch 1/20 | RMSE Val: 17.0949
# Epoch 2/20 | RMSE Val: 7.8759
# Epoch 3/20 | RMSE Val: 7.3834
# Epoch 4/20 | RMSE Val: 7.1299
# Epoch 5/20 | RMSE Val: 7.0085
# Epoch 6/20 | RMSE Val: 6.9338
# Epoch 7/20 | RMSE Val: 6.8699
# Epoch 8/20 | RMSE Val: 6.8167
# Epoch 9/20 | RMSE Val: 6.7812
# Epoch 10/20 | RMSE Val: 6.7330
# Epoch 11/20 | RMSE Val: 6.6976
# Epoch 12/20 | RMSE Val: 6.6649
# Epoch 13/20 | RMSE Val: 6.6359
# Epoch 14/20 | RMSE Val: 6.6097
# Epoch 15/20 | RMSE Val: 6.5891
# Epoch 16/20 | RMSE Val: 6.5673
# Epoch 17/20 | RMSE Val: 6.5508
# Epoch 18/20 | RMSE Val: 6.5299
# Epoch 19/20 | RMSE Val: 6.5103
# Epoch 20/20 | RMSE Val: 6.4966

# %%
# Séparer test en 3 modes
BLOCK_test = len(test) // 3
test1 = test.iloc[0           : BLOCK_test].copy()
test2 = test.iloc[BLOCK_test  : 2*BLOCK_test].copy()
test3 = test.iloc[2*BLOCK_test:].copy()

def predict_mlp(model, test_df, features):
    """Prédit les températures avec un MLP."""
    model.eval()
    X = torch.tensor(test_df[features].values, dtype=torch.float32).to(device)
    with torch.no_grad():
        return model(X).cpu().numpy().flatten()

y_pred1 = predict_mlp(model1, test1, features)
y_pred2 = predict_mlp(model2, test2, features)
y_pred3 = predict_mlp(model3, test3, features)

y_pred = np.concatenate([y_pred1, y_pred2, y_pred3])
print(f"Prédictions totales : {len(y_pred)}")
print(f"Min: {y_pred.min():.2f}, Max: {y_pred.max():.2f}")
# Out:
# Prédictions totales : 2190480
# Min: -0.90, Max: 78.78

# %% [markdown]
# # SETUP FOR MODELS TRAINING (LEADERBOARD)

# %%
import numpy as np
import pandas as pd
#test = pd.read_parquet("data/data_parquet_2026/test.parquet")
# Replace this with your real model predictions.
#y_pred = np.zeros(len(test), dtype=float)
submission = pd.DataFrame({
   "Id": np.arange(len(test), dtype=int),
   "temperature": y_pred,
})
assert list(submission.columns) == ["Id", "temperature"]
assert len(submission) == len(test)
assert (submission["Id"].to_numpy() == np.arange(len(test))).all()
assert np.isfinite(submission["temperature"]).all()
assert submission.isna().sum().sum() == 0
submission.to_csv("submission.csv", index=False)
print("Saved submission.csv")
# Out:
# Saved submission.csv
